# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras import optimizers
import tensorflow as tf 
import keras
import keras.backend as K
from keras.layers.core import Activation
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout
import joblib
import itertools
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Ingrid"
# Out:
# /content/drive/MyDrive/Ingrid

# %% [markdown]
# ## Lendo Dados

# %%
df= pd.read_csv('data_05_shaft_bearing.csv')

# %% [markdown]
# ## Carregando Dados

# %%
df= df.dropna()
df=df[df['power']>100]
df= df[df['outdoor_temp']>0]
df= df[df['nacelle']>0]
df= df[df['generator_speed']>0]
df= df[df['gearbox_bearing']>0]
df.drop(columns=["Unnamed: 0"],inplace=True)
print(df)

features = ['generator_speed', 'nacelle']
target = ['gearbox_bearing']
X = df[features]
y = df[target]

PredictorScaler=StandardScaler()
TargetVarScaler=StandardScaler()
PredictorScalerFit=PredictorScaler.fit(X)
TargetVarScalerFit=TargetVarScaler.fit(y)
X=PredictorScalerFit.transform(X)
y=TargetVarScalerFit.transform(y)
# Out:
#                       sample_time      power  outdoor_temp  generator_speed  \
# 0       2018-01-01 00:00:00+00:00  668.28204     32.369460        973.59010
# 1       2018-01-01 00:10:00+00:00  396.09955     32.322247        851.24150
# 2       2018-01-01 00:20:00+00:00  337.86740     32.230736        835.06190
# 3       2018-01-01 00:30:00+00:00  326.90180     32.051624        830.00200
# 4       2018-01-01 00:40:00+00:00  400.90637     31.891493        843.18300
# ...                           ...        ...           ...              ...
# 157809  2020-12-31 21:30:00+00:00  463.78204     30.680513        886.92694
# 157810  2020-12-31 21:40:00+00:00  472.37115     30.551275        884.98804
# 157811  2020-12-31 21:50:00+00:00  579.70490     30.431310        939.09460
# 157812  2020-12-31 22:00:00+00:00  554.78850     30.328987        927.96220
# 157813  2020-12-31 22:10:00+00:00  194.68222     30.234390        352.50555
#
#           nacelle  gearbox_bearing
# 0       39.058334        64.715836
# 1       38.784668        64.043500
# 2       38.634502        63.263668
# 3       38.470500        62.612000
# 4       38.342167        62.464000
# ...           ...              ...
# 157809  39.403336        65.438670
# 157810  39.182835        64.908165
# 157811  39.011333        64.766170
# 157812  38.867000        64.691170
# 157813  40.111168        63.903500
#
# [129814 rows x 6 columns]

# %% [markdown]
# ## Construindo o Dataset

# %%
X_train= X[0:100000]
y_train= y[0:100000]
X_validation = X[10000:105120]
y_validation = y[10000:105120]
X_test= X[105120:]
y_test= y[105120:]
#print(len(y_test))


#X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))
#y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1],1))
#X_validation = np.reshape(X_train, (X_validation.shape[0], 1, X_validation.shape[1]))

# %% [markdown]
# ## Função Plot_Grid

# %%
def Plot_Grid(grid,x,metric,scale_y,namefig):
  sns.set_theme(style="whitegrid")

  plt.rcParams["figure.figsize"] = [scale_y[0], scale_y[1]]
  plt.rcParams["figure.autolayout"] = True

  Grid_List = []

  k_0 = list(grid.keys())[0].split("/")

  del(k_0[-1])

  id_x = ""
  for i in range(len(k_0)):
    if(k_0[i].split(":")[0] == x):
      id_x = i
      break

  combinations = {metric:[],x:[],"hue":[]}

  for key in list(grid.keys()):

    combinations[metric].append(grid[key])

    aux = key.split("/")
    del(aux[-1])

    combinations[x].append(aux[id_x].split(":")[1])

    h = ""
    for j in range(len(aux)):
      if( j!= id_x):
        h += aux[j] + "/"

    combinations["hue"].append(h)



  dataframe = pd.DataFrame(combinations)

  g = sns.catplot(
  data=dataframe, kind="bar",
  x=x, y=metric, hue="hue",
  ci="sd", palette="dark", alpha=.6, height=6
  )
  plt.ylim(scale_y[0], scale_y[1])
  g.despine(left=True)
  g.set_axis_labels(x, metric)
  g.legend.set_title("")
  plt.savefig(namefig + ".png")

    # Alguma forma de ficar setando o tamanho da imagem

# %% [markdown]
# ## Função R2

# %%
from keras import backend as K

def coeff_determination(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %% [markdown]
# ## Parâmetros

# %%
grid_name = "ANN_75"
epochs = [100]
optimizer = ["adam"]
la1 = [100]
la2 = [100]
batch_size = [60]
activation = ["selu"]
learning_rate = [0.0001]

params = [("batch_size",batch_size), ("epochs",epochs), ("optimizer",optimizer),
          ("la1", la1), ("la2", la2), ("activation", activation),("learning_rate",learning_rate), ("dropout",dropout)]

# %% [markdown]
# ## Model

# %%
def create_model(la1,la2,activation,optmizer):

  model = Sequential()
  model.add(Dense(la1,activation=activation))
  model.add(Dense(la2,activation=activation))
  model.add(Dense(la2,activation=activation))
  model.add(Dense(1, activation=activation))
  model.add(Dense(1, activation=activation))
  model.add(Dense(1, activation=activation))
  model.compile(optimizer=optmizer, loss="mse", metrics=[coeff_determination])
  return model

# %% [markdown]
# ## GridSearch LSTM

# %%
index = 0
Grid = {}
param_legends = []
all = len(list(itertools.product(batch_size, epochs, la1, la2, optimizer, activation)))

for pr in params:
  if(len(pr[1])>1):
    param_legends.append(pr[0])

for (bs, ep, l1, l2, opt, ac, lr) in itertools.product(batch_size, epochs, la1, la2, optimizer, activation, learning_rate):


  model = create_model(l1,l2,ac,tf.keras.optimizers.Adam(learning_rate=lr))
  model.fit(X_train, y_train , batch_size = bs, epochs= ep)
  results = model.evaluate(X_test, y_test, batch_size= 128)

  key_string = ""

  for pr_lg in param_legends:

    if(pr_lg == "batch_size"):
      key_string = key_string + pr_lg + ":" + str(bs) + "/"

    if(pr_lg == "epochs"):
      key_string = key_string + pr_lg + ":" + str(ep) + "/"

    if(pr_lg == "la1"):
      key_string = key_string + pr_lg + ":" + str(l1) + "/"

    if(pr_lg == "la2"):
      key_string = key_string + pr_lg + ":" + str(l2) + "/"

    if(pr_lg == "optimizer"):
      key_string = key_string + pr_lg + ":" + str(opt) + "/"

    if(pr_lg == "activation"):
      key_string = key_string + pr_lg + ":" + str(ac) + "/"

    if(pr_lg == "learning_rate"):
      key_string = key_string + pr_lg + ":" + str(lr) + "/"

  
  Grid[key_string] = results[1]

  percent_process = round(index/all,2)

  if(index % 10 == 0):
    joblib.dump(Grid, grid_name + "_" + "process_" + str(percent_process)+ ".pkl")

  index = index + 1
# Out:
# Epoch 1/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.5146 - coeff_determination: 0.5103
# Epoch 2/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.4236 - coeff_determination: 0.5959
# Epoch 3/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3828 - coeff_determination: 0.6339
# Epoch 4/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3634 - coeff_determination: 0.6521
# Epoch 5/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3532 - coeff_determination: 0.6617
# Epoch 6/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3481 - coeff_determination: 0.6657
# Epoch 7/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3448 - coeff_determination: 0.6686
# Epoch 8/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3425 - coeff_determination: 0.6712
# Epoch 9/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3413 - coeff_determination: 0.6722
# Epoch 10/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3400 - coeff_determination: 0.6729
# Epoch 11/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3393 - coeff_determination: 0.6733
# Epoch 12/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3385 - coeff_determination: 0.6737
# Epoch 13/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3384 - coeff_determination: 0.6732
# Epoch 14/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3373 - coeff_determination: 0.6749
# Epoch 15/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3367 - coeff_determination: 0.6754
# Epoch 16/100
# 1667/1667 [==============================] - 4s 3ms/step - loss: 0.3364 - coeff_determination: 0.6764
# Epoch 17/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3359 - coeff_determination: 0.6757
# Epoch 18/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3359 - coeff_determination: 0.6766
# Epoch 19/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3351 - coeff_determination: 0.6770
# Epoch 20/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3352 - coeff_determination: 0.6763
# Epoch 21/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3345 - coeff_determination: 0.6775
# Epoch 22/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3344 - coeff_determination: 0.6775
# Epoch 23/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3345 - coeff_determination: 0.6775
# Epoch 24/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3343 - coeff_determination: 0.6771
# Epoch 25/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3339 - coeff_determination: 0.6779
# Epoch 26/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3335 - coeff_determination: 0.6786
# Epoch 27/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3336 - coeff_determination: 0.6777
# Epoch 28/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3334 - coeff_determination: 0.6781
# Epoch 29/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3332 - coeff_determination: 0.6784
# Epoch 30/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3330 - coeff_determination: 0.6781
# Epoch 31/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3326 - coeff_determination: 0.6789
# Epoch 32/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3327 - coeff_determination: 0.6795
# Epoch 33/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3326 - coeff_determination: 0.6790
# Epoch 34/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3326 - coeff_determination: 0.6799
# Epoch 35/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3322 - coeff_determination: 0.6801
# Epoch 36/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3327 - coeff_determination: 0.6791
# Epoch 37/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3326 - coeff_determination: 0.6789
# Epoch 38/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3322 - coeff_determination: 0.6796
# Epoch 39/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3322 - coeff_determination: 0.6793
# Epoch 40/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3319 - coeff_determination: 0.6802
# Epoch 41/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3317 - coeff_determination: 0.6804
# Epoch 42/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3319 - coeff_determination: 0.6805
# Epoch 43/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3319 - coeff_determination: 0.6801
# Epoch 44/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3314 - coeff_determination: 0.6810
# Epoch 45/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3320 - coeff_determination: 0.6799
# Epoch 46/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3315 - coeff_determination: 0.6798
# Epoch 47/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3315 - coeff_determination: 0.6800
# Epoch 48/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3315 - coeff_determination: 0.6805
# Epoch 49/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3316 - coeff_determination: 0.6800
# Epoch 50/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3315 - coeff_determination: 0.6797
# Epoch 51/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3316 - coeff_determination: 0.6794
# Epoch 52/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3314 - coeff_determination: 0.6797
# Epoch 53/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3312 - coeff_determination: 0.6798
# Epoch 54/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3311 - coeff_determination: 0.6806
# Epoch 55/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3310 - coeff_determination: 0.6801
# Epoch 56/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3309 - coeff_determination: 0.6807
# Epoch 57/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3313 - coeff_determination: 0.6803
# Epoch 58/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3310 - coeff_determination: 0.6808
# Epoch 59/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3312 - coeff_determination: 0.6808
# Epoch 60/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3309 - coeff_determination: 0.6809
# Epoch 61/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3308 - coeff_determination: 0.6818
# Epoch 62/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3307 - coeff_determination: 0.6804
# Epoch 63/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3306 - coeff_determination: 0.6806
# Epoch 64/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3306 - coeff_determination: 0.6802
# Epoch 65/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3308 - coeff_determination: 0.6815
# Epoch 66/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3306 - coeff_determination: 0.6815
# Epoch 67/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3304 - coeff_determination: 0.6804
# Epoch 68/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3304 - coeff_determination: 0.6816
# Epoch 69/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3300 - coeff_determination: 0.6820
# Epoch 70/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3304 - coeff_determination: 0.6812
# Epoch 71/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3304 - coeff_determination: 0.6805
# Epoch 72/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3303 - coeff_determination: 0.6816
# Epoch 73/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3301 - coeff_determination: 0.6815
# Epoch 74/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3303 - coeff_determination: 0.6822
# Epoch 75/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3301 - coeff_determination: 0.6815
# Epoch 76/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3299 - coeff_determination: 0.6816
# Epoch 77/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3300 - coeff_determination: 0.6822
# Epoch 78/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3297 - coeff_determination: 0.6823
# Epoch 79/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3301 - coeff_determination: 0.6816
# Epoch 80/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3299 - coeff_determination: 0.6810
# Epoch 81/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3298 - coeff_determination: 0.6821
# Epoch 82/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3299 - coeff_determination: 0.6819
# Epoch 83/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3299 - coeff_determination: 0.6811
# Epoch 84/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3297 - coeff_determination: 0.6822
# Epoch 85/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3297 - coeff_determination: 0.6819
# Epoch 86/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3299 - coeff_determination: 0.6821
# Epoch 87/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3298 - coeff_determination: 0.6816
# Epoch 88/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3297 - coeff_determination: 0.6825
# Epoch 89/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3294 - coeff_determination: 0.6829
# Epoch 90/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3296 - coeff_determination: 0.6819
# Epoch 91/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3296 - coeff_determination: 0.6826
# Epoch 92/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3297 - coeff_determination: 0.6815
# Epoch 93/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3298 - coeff_determination: 0.6816
# Epoch 94/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3293 - coeff_determination: 0.6825
# Epoch 95/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3295 - coeff_determination: 0.6815
# Epoch 96/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3296 - coeff_determination: 0.6820
# Epoch 97/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3293 - coeff_determination: 0.6817
# Epoch 98/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3294 - coeff_determination: 0.6811
# Epoch 99/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3293 - coeff_determination: 0.6825
# Epoch 100/100
# 1667/1667 [==============================] - 4s 2ms/step - loss: 0.3294 - coeff_determination: 0.6813
# 193/193 [==============================] - 0s 2ms/step - loss: 0.4054 - coeff_determination: 0.2035

# %% [markdown]
# ## Plot Grid

# %%
#Grid_Load = joblib.load("teste_1_process_0.0.pkl")

# %%
Grid
# Out:
# {'': 0.2034885585308075}

# %%
Plot_Grid(Grid,"dropout","r2-score",(-1,1),grid_name)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-eeeda1f40eae> in <module>()
# ----> 1 Plot_Grid(Grid,"dropout","r2-score",(-1,1),grid_name)
#
# <ipython-input-7-399764571603> in Plot_Grid(grid, x, metric, scale_y, namefig)
#      26     del(aux[-1])
#      27
# ---> 28     combinations[x].append(aux[id_x].split(":")[1])
#      29
#      30     h = ""
#
# TypeError: list indices must be integers or slices, not str
